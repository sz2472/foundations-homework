# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("2016-FCC-New-Coders-Survey-Data.csv")
# Out:
# /usr/local/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (21,57) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0      28.0               0.0             NaN                   NaN
# 1      22.0               0.0             NaN                   NaN
# 2      19.0               0.0             NaN                   NaN
# 3      26.0               0.0             NaN                   NaN
# 4      20.0               0.0             NaN                   NaN
# 5      34.0               0.0             NaN                   NaN
# 6      23.0               0.0             NaN                   NaN
# 7      35.0               0.0             NaN                   NaN
# 8      33.0               0.0             NaN                   NaN
# 9      33.0               0.0             NaN                   NaN
# 10     57.0               0.0             NaN                   NaN
# 11     23.0               0.0             NaN                   NaN
# 12     47.0               0.0             NaN                   NaN
# 13      NaN               0.0             NaN                   NaN
# 14     37.0               0.0             NaN                   NaN
# 15     31.0               0.0             NaN                   NaN
# 16     27.0               0.0             NaN                   NaN
# 17     29.0               0.0             NaN                   NaN
# 18     30.0               0.0             NaN                   NaN
# 19     30.0               0.0             NaN                   NaN
# 20     32.0               0.0             NaN                   NaN
# 21     25.0               0.0             NaN                   NaN
# 22     29.0               0.0             NaN                   NaN
# 23     44.0               0.0             NaN                   NaN
# 24     21.0               0.0             NaN                   NaN
# 25     21.0               0.0             NaN                   NaN
# 26     28.0               0.0             NaN                   NaN
# 27     28.0               0.0             NaN                   NaN
# 28     25.0               0.0             NaN                   NaN
# 29     35.0               0.0             NaN                   NaN
# ...     ...               ...             ...                   ...
# 15590  25.0               0.0             NaN                   NaN
# 15591  25.0               0.0             NaN                   NaN
# 15592  43.0               0.0             NaN                   NaN
# 15593  29.0               1.0             0.0                   NaN
# 15594  36.0               0.0             NaN                   NaN
# 15595  30.0               0.0             NaN                   NaN
# 15596  30.0               0.0             NaN                   NaN
# 15597  30.0               0.0             NaN                   NaN
# 15598  28.0               0.0             NaN                   NaN
# 15599  37.0               0.0             NaN                   NaN
# 15600  28.0               1.0             1.0                   1.0
# 15601  25.0               0.0             NaN                   NaN
# 15602  22.0               0.0             NaN                   NaN
# 15603  33.0               0.0             NaN                   NaN
# 15604  35.0               0.0             NaN                   NaN
# 15605  31.0               0.0             NaN                   NaN
# 15606  43.0               0.0             NaN                   NaN
# 15607  25.0               0.0             NaN                   NaN
# 15608  43.0               0.0             NaN                   NaN
# 15609  33.0               0.0             NaN                   NaN
# 15610  29.0               0.0             NaN                   NaN
# 15611  37.0               0.0             NaN                   NaN
# 15612  45.0               0.0             NaN                   NaN
# 15613  30.0               0.0             NaN                   NaN
# 15614  47.0               0.0             NaN                   NaN
# 15615  39.0               0.0             NaN                   NaN
# 15616  27.0               0.0             NaN                   NaN
# 15617  37.0               0.0             NaN                   NaN
# 15618  26.0               0.0             NaN                   NaN
# 15619  22.0               0.0             NaN                   NaN
#
#        BootcampLoanYesNo  BootcampMonthsAgo    BootcampName  \
# 0                    NaN                NaN             NaN
# 1                    NaN                NaN             NaN
# 2                    NaN                NaN             NaN
# 3                    NaN                NaN             NaN
# 4                    NaN                NaN             NaN
# 5                    NaN                NaN             NaN
# 6                    NaN                NaN             NaN
# 7                    NaN                NaN             NaN
# 8                    NaN                NaN             NaN
# 9                    NaN                NaN             NaN
# 10                   NaN                NaN             NaN
# 11                   NaN                NaN             NaN
# 12                   NaN                NaN             NaN
# 13                   NaN                NaN             NaN
# 14                   NaN                NaN             NaN
# 15                   NaN                NaN             NaN
# 16                   NaN                NaN             NaN
# 17                   NaN                NaN             NaN
# 18                   NaN                NaN             NaN
# 19                   NaN                NaN             NaN
# 20                   NaN                NaN             NaN
# 21                   NaN                NaN             NaN
# 22                   NaN                NaN             NaN
# 23                   NaN                NaN             NaN
# 24                   NaN                NaN             NaN
# 25                   NaN                NaN             NaN
# 26                   NaN                NaN             NaN
# 27                   NaN                NaN             NaN
# 28                   NaN                NaN             NaN
# 29                   NaN                NaN             NaN
# ...                  ...                ...             ...
# 15590                NaN                NaN             NaN
# 15591                NaN                NaN             NaN
# 15592                NaN                NaN             NaN
# 15593                0.0                NaN  Camp Code Away
# 15594                NaN                NaN             NaN
# 15595                NaN                NaN             NaN
# 15596                NaN                NaN             NaN
# 15597                NaN                NaN             NaN
# 15598                NaN                NaN             NaN
# 15599                NaN                NaN             NaN
# 15600                0.0                4.0        Epicodus
# 15601                NaN                NaN             NaN
# 15602                NaN                NaN             NaN
# 15603                NaN                NaN             NaN
# 15604                NaN                NaN             NaN
# 15605                NaN                NaN             NaN
# 15606                NaN                NaN             NaN
# 15607                NaN                NaN             NaN
# 15608                NaN                NaN             NaN
# 15609                NaN                NaN             NaN
# 15610                NaN                NaN             NaN
# 15611                NaN                NaN             NaN
# 15612                NaN                NaN             NaN
# 15613                NaN                NaN             NaN
# 15614                NaN                NaN             NaN
# 15615                NaN                NaN             NaN
# 15616                NaN                NaN             NaN
# 15617                NaN                NaN             NaN
# 15618                NaN                NaN             NaN
# 15619                NaN                NaN             NaN
#
#        BootcampPostSalary  BootcampRecommend  ChildrenNumber       ...        \
# 0                     NaN                NaN             NaN       ...
# 1                     NaN                NaN             NaN       ...
# 2                     NaN                NaN             NaN       ...
# 3                     NaN                NaN             NaN       ...
# 4                     NaN                NaN             NaN       ...
# 5                     NaN                NaN             NaN       ...
# 6                     NaN                NaN             NaN       ...
# 7                     NaN                NaN             NaN       ...
# 8                     NaN                NaN             NaN       ...
# 9                     NaN                NaN             NaN       ...
# 10                    NaN                NaN             NaN       ...
# 11                    NaN                NaN             NaN       ...
# 12                    NaN                NaN             NaN       ...
# 13                    NaN                NaN             NaN       ...
# 14                    NaN                NaN             1.0       ...
# 15                    NaN                NaN             NaN       ...
# 16                    NaN                NaN             NaN       ...
# 17                    NaN                NaN             NaN       ...
# 18                    NaN                NaN             NaN       ...
# 19                    NaN                NaN             NaN       ...
# 20                    NaN                NaN             1.0       ...
# 21                    NaN                NaN             NaN       ...
# 22                    NaN                NaN             NaN       ...
# 23                    NaN                NaN             NaN       ...
# 24                    NaN                NaN             NaN       ...
# 25                    NaN                NaN             NaN       ...
# 26                    NaN                NaN             NaN       ...
# 27                    NaN                NaN             2.0       ...
# 28                    NaN                NaN             NaN       ...
# 29                    NaN                NaN             1.0       ...
# ...                   ...                ...             ...       ...
# 15590                 NaN                NaN             NaN       ...
# 15591                 NaN                NaN             NaN       ...
# 15592                 NaN                NaN             1.0       ...
# 15593                 NaN                0.0             NaN       ...
# 15594                 NaN                NaN             2.0       ...
# 15595                 NaN                NaN             NaN       ...
# 15596                 NaN                NaN             2.0       ...
# 15597                 NaN                NaN             NaN       ...
# 15598                 NaN                NaN             1.0       ...
# 15599                 NaN                NaN             NaN       ...
# 15600             36000.0                1.0             NaN       ...
# 15601                 NaN                NaN             NaN       ...
# 15602                 NaN                NaN             NaN       ...
# 15603                 NaN                NaN             NaN       ...
# 15604                 NaN                NaN             NaN       ...
# 15605                 NaN                NaN             NaN       ...
# 15606                 NaN                NaN             3.0       ...
# 15607                 NaN                NaN             NaN       ...
# 15608                 NaN                NaN             2.0       ...
# 15609                 NaN                NaN             NaN       ...
# 15610                 NaN                NaN             NaN       ...
# 15611                 NaN                NaN             1.0       ...
# 15612                 NaN                NaN             NaN       ...
# 15613                 NaN                NaN             2.0       ...
# 15614                 NaN                NaN             NaN       ...
# 15615                 NaN                NaN             NaN       ...
# 15616                 NaN                NaN             NaN       ...
# 15617                 NaN                NaN             NaN       ...
# 15618                 NaN                NaN             NaN       ...
# 15619                 NaN                NaN             NaN       ...
#
#       ResourceSoloLearn  ResourceStackOverflow  ResourceTreehouse  \
# 0                   NaN                    NaN                NaN
# 1                   NaN                    NaN                NaN
# 2                   NaN                    NaN                NaN
# 3                   NaN                    NaN                NaN
# 4                   NaN                    NaN                NaN
# 5                   NaN                    NaN                NaN
# 6                   NaN                    NaN                NaN
# 7                   NaN                    NaN                NaN
# 8                   NaN                    NaN                NaN
# 9                   NaN                    NaN                NaN
# 10                  NaN                    NaN                NaN
# 11                  NaN                    NaN                NaN
# 12                  NaN                    NaN                NaN
# 13                  NaN                    NaN                NaN
# 14                  NaN                    NaN                NaN
# 15                  NaN                    NaN                NaN
# 16                  NaN                    NaN                NaN
# 17                  NaN                    NaN                NaN
# 18                  NaN                    NaN                NaN
# 19                  NaN                    NaN                NaN
# 20                  NaN                    NaN                NaN
# 21                  NaN                    NaN                NaN
# 22                  NaN                    NaN                NaN
# 23                  NaN                    NaN                NaN
# 24                  NaN                    NaN                NaN
# 25                  NaN                    NaN                NaN
# 26                  NaN                    NaN                NaN
# 27                  NaN                    NaN                1.0
# 28                  NaN                    NaN                NaN
# 29                  NaN                    NaN                NaN
# ...                 ...                    ...                ...
# 15590               NaN                    NaN                NaN
# 15591               NaN                    NaN                NaN
# 15592               NaN                    NaN                NaN
# 15593               NaN                    NaN                NaN
# 15594               NaN                    NaN                NaN
# 15595               NaN                    NaN                NaN
# 15596               NaN                    NaN                NaN
# 15597               NaN                    NaN                NaN
# 15598               NaN                    NaN                NaN
# 15599               NaN                    NaN                NaN
# 15600               NaN                    NaN                NaN
# 15601               NaN                    NaN                NaN
# 15602               NaN                    NaN                NaN
# 15603               NaN                    NaN                NaN
# 15604               NaN                    NaN                NaN
# 15605               NaN                    NaN                NaN
# 15606               NaN                    NaN                NaN
# 15607               NaN                    NaN                NaN
# 15608               NaN                    NaN                NaN
# 15609               NaN                    NaN                NaN
# 15610               NaN                    NaN                NaN
# 15611               NaN                    NaN                NaN
# 15612               NaN                    NaN                NaN
# 15613               NaN                    NaN                NaN
# 15614               NaN                    NaN                NaN
# 15615               NaN                    NaN                NaN
# 15616               NaN                    NaN                1.0
# 15617               NaN                    NaN                NaN
# 15618               NaN                    NaN                NaN
# 15619               NaN                    NaN                NaN
#
#        ResourceUdacity  ResourceUdemy  ResourceW3Schools  ResourceYouTube  \
# 0                  NaN            NaN                NaN              NaN
# 1                  NaN            1.0                NaN              NaN
# 2                  NaN            NaN                NaN              NaN
# 3                  NaN            NaN                NaN              NaN
# 4                  NaN            NaN                NaN              NaN
# 5                  NaN            NaN                NaN              NaN
# 6                  NaN            NaN                NaN              NaN
# 7                  NaN            NaN                NaN              NaN
# 8                  1.0            NaN                NaN              NaN
# 9                  NaN            NaN                NaN              NaN
# 10                 NaN            NaN                NaN              NaN
# 11                 NaN            NaN                NaN              NaN
# 12                 1.0            1.0                NaN              NaN
# 13                 NaN            NaN                NaN              NaN
# 14                 1.0            NaN                NaN              NaN
# 15                 NaN            NaN                NaN              NaN
# 16                 1.0            NaN                NaN              NaN
# 17                 NaN            NaN                NaN              NaN
# 18                 NaN            NaN                NaN              NaN
# 19                 1.0            NaN                NaN              NaN
# 20                 1.0            1.0                NaN              NaN
# 21                 NaN            NaN                NaN              NaN
# 22                 NaN            NaN                NaN              NaN
# 23                 1.0            1.0                NaN              NaN
# 24                 1.0            NaN                NaN              NaN
# 25                 NaN            NaN                NaN              NaN
# 26                 NaN            NaN                NaN              NaN
# 27                 NaN            NaN                NaN              NaN
# 28                 NaN            NaN                NaN              NaN
# 29                 NaN            NaN                NaN              NaN
# ...                ...            ...                ...              ...
# 15590              NaN            NaN                NaN              NaN
# 15591              NaN            NaN                NaN              NaN
# 15592              NaN            NaN                NaN              NaN
# 15593              NaN            NaN                NaN              NaN
# 15594              NaN            NaN                NaN              NaN
# 15595              NaN            NaN                NaN              NaN
# 15596              NaN            NaN                NaN              NaN
# 15597              NaN            NaN                NaN              NaN
# 15598              1.0            NaN                NaN              NaN
# 15599              NaN            NaN                NaN              NaN
# 15600              NaN            NaN                NaN              NaN
# 15601              1.0            1.0                NaN              NaN
# 15602              1.0            NaN                NaN              NaN
# 15603              NaN            NaN                NaN              NaN
# 15604              NaN            1.0                NaN              NaN
# 15605              NaN            NaN                NaN              NaN
# 15606              NaN            1.0                NaN              NaN
# 15607              NaN            1.0                NaN              NaN
# 15608              1.0            NaN                NaN              NaN
# 15609              NaN            NaN                NaN              NaN
# 15610              NaN            NaN                NaN              NaN
# 15611              1.0            NaN                NaN              NaN
# 15612              NaN            1.0                NaN              NaN
# 15613              NaN            1.0                NaN              NaN
# 15614              NaN            NaN                NaN              NaN
# 15615              NaN            1.0                NaN              NaN
# 15616              NaN            NaN                NaN              NaN
# 15617              NaN            NaN                NaN              NaN
# 15618              NaN            1.0                NaN              NaN
# 15619              NaN            NaN                NaN              NaN
#
#                                    SchoolDegree  \
# 0                some college credit, no degree
# 1                some college credit, no degree
# 2       high school diploma or equivalent (GED)
# 3                             bachelor's degree
# 4                some college credit, no degree
# 5                             bachelor's degree
# 6                             bachelor's degree
# 7            master's degree (non-professional)
# 8                             bachelor's degree
# 9            master's degree (non-professional)
# 10                            bachelor's degree
# 11               some college credit, no degree
# 12                            bachelor's degree
# 13                            bachelor's degree
# 14               some college credit, no degree
# 15      professional degree (MBA, MD, JD, etc.)
# 16                            bachelor's degree
# 17                            bachelor's degree
# 18                            bachelor's degree
# 19               some college credit, no degree
# 20           master's degree (non-professional)
# 21                            bachelor's degree
# 22                            bachelor's degree
# 23                            bachelor's degree
# 24                            bachelor's degree
# 25               some college credit, no degree
# 26      high school diploma or equivalent (GED)
# 27     trade, technical, or vocational training
# 28                            bachelor's degree
# 29           master's degree (non-professional)
# ...                                         ...
# 15590                         bachelor's degree
# 15591   professional degree (MBA, MD, JD, etc.)
# 15592   high school diploma or equivalent (GED)
# 15593                         bachelor's degree
# 15594                         bachelor's degree
# 15595                          some high school
# 15596   high school diploma or equivalent (GED)
# 15597   professional degree (MBA, MD, JD, etc.)
# 15598                        associate's degree
# 15599            some college credit, no degree
# 15600                         bachelor's degree
# 15601                         bachelor's degree
# 15602                         bachelor's degree
# 15603                         bachelor's degree
# 15604            some college credit, no degree
# 15605   high school diploma or equivalent (GED)
# 15606                         bachelor's degree
# 15607         no high school (secondary school)
# 15608   professional degree (MBA, MD, JD, etc.)
# 15609                         bachelor's degree
# 15610        master's degree (non-professional)
# 15611   professional degree (MBA, MD, JD, etc.)
# 15612            some college credit, no degree
# 15613  trade, technical, or vocational training
# 15614  trade, technical, or vocational training
# 15615                         bachelor's degree
# 15616                         bachelor's degree
# 15617                         bachelor's degree
# 15618        master's degree (non-professional)
# 15619                         bachelor's degree
#
#                                              SchoolMajor  StudentDebtOwe
# 0                                                    NaN         20000.0
# 1                                                    NaN             NaN
# 2                                                    NaN             NaN
# 3                                Cinematography And Film          7000.0
# 4                                                    NaN             NaN
# 5                                                English             NaN
# 6                                       Computer Science             NaN
# 7                                              Education             NaN
# 8                                Business Administration             NaN
# 9                                Business Administration        180000.0
# 10                                      Computer Science             NaN
# 11                                                   NaN             NaN
# 12                                Mechanical Engineering             NaN
# 13                               Business Administration         12000.0
# 14                                                   NaN             NaN
# 15                                                  Math             NaN
# 16                                             Economics             NaN
# 17                                                 Music             NaN
# 18                                                 Music             NaN
# 19                                                   NaN             NaN
# 20                                               Geology             NaN
# 21                                      Computer Science             NaN
# 22                                      Computer Science             NaN
# 23                                     Political Science         50000.0
# 24                                      Computer Science             NaN
# 25                                                   NaN         40000.0
# 26                                                   NaN             NaN
# 27                                                   NaN             NaN
# 28                                     Political Science             NaN
# 29                                               Physics             NaN
# ...                                                  ...             ...
# 15590                                   Computer Science             NaN
# 15591  Computer Systems Networking and Telecommunicat...             NaN
# 15592                                                NaN             NaN
# 15593                                         Accounting             NaN
# 15594                                        Engineering             NaN
# 15595                                                NaN             NaN
# 15596                                                NaN             NaN
# 15597                                                Law             NaN
# 15598          Computer and Information Systems Security         12000.0
# 15599                                                NaN             NaN
# 15600                                          Marketing             NaN
# 15601                Criminal Justice and Safety Studies             NaN
# 15602                                        Mathematics             NaN
# 15603                                   Computer Science             NaN
# 15604                                                NaN             NaN
# 15605                                                NaN             NaN
# 15606                                            Physics             NaN
# 15607                                                NaN             NaN
# 15608                             Electrical Engineering             NaN
# 15609                               Software Engineering         15000.0
# 15610                                  Religious Studies         26000.0
# 15611             Electrical and Electronics Engineering             NaN
# 15612                                                NaN         30000.0
# 15613                                                NaN             NaN
# 15614                                                NaN             NaN
# 15615                                          Chemistry             NaN
# 15616                             Electrical Engineering             NaN
# 15617                                          Chemistry             NaN
# 15618                                               Math             NaN
# 15619                                     Graphic Design         40000.0
#
# [15620 rows x 113 columns]

# %%
df.tail()
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 15615  39.0               0.0             NaN                   NaN
# 15616  27.0               0.0             NaN                   NaN
# 15617  37.0               0.0             NaN                   NaN
# 15618  26.0               0.0             NaN                   NaN
# 15619  22.0               0.0             NaN                   NaN
#
#        BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 15615                NaN                NaN          NaN                 NaN
# 15616                NaN                NaN          NaN                 NaN
# 15617                NaN                NaN          NaN                 NaN
# 15618                NaN                NaN          NaN                 NaN
# 15619                NaN                NaN          NaN                 NaN
#
#        BootcampRecommend  ChildrenNumber       ...       ResourceSoloLearn  \
# 15615                NaN             NaN       ...                     NaN
# 15616                NaN             NaN       ...                     NaN
# 15617                NaN             NaN       ...                     NaN
# 15618                NaN             NaN       ...                     NaN
# 15619                NaN             NaN       ...                     NaN
#
#        ResourceStackOverflow  ResourceTreehouse  ResourceUdacity  \
# 15615                    NaN                NaN              NaN
# 15616                    NaN                1.0              NaN
# 15617                    NaN                NaN              NaN
# 15618                    NaN                NaN              NaN
# 15619                    NaN                NaN              NaN
#
#        ResourceUdemy  ResourceW3Schools  ResourceYouTube  \
# 15615            1.0                NaN              NaN
# 15616            NaN                NaN              NaN
# 15617            NaN                NaN              NaN
# 15618            1.0                NaN              NaN
# 15619            NaN                NaN              NaN
#
#                              SchoolDegree             SchoolMajor  \
# 15615                   bachelor's degree               Chemistry
# 15616                   bachelor's degree  Electrical Engineering
# 15617                   bachelor's degree               Chemistry
# 15618  master's degree (non-professional)                    Math
# 15619                   bachelor's degree          Graphic Design
#
#        StudentDebtOwe
# 15615             NaN
# 15616             NaN
# 15617             NaN
# 15618             NaN
# 15619         40000.0
#
# [5 rows x 113 columns]

# %%
df[6:9]
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 6  23.0               0.0             NaN                   NaN
# 7  35.0               0.0             NaN                   NaN
# 8  33.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 6                NaN                NaN          NaN                 NaN
# 7                NaN                NaN          NaN                 NaN
# 8                NaN                NaN          NaN                 NaN
#
#    BootcampRecommend  ChildrenNumber       ...       ResourceSoloLearn  \
# 6                NaN             NaN       ...                     NaN
# 7                NaN             NaN       ...                     NaN
# 8                NaN             NaN       ...                     NaN
#
#    ResourceStackOverflow  ResourceTreehouse  ResourceUdacity  ResourceUdemy  \
# 6                    NaN                NaN              NaN            NaN
# 7                    NaN                NaN              NaN            NaN
# 8                    NaN                NaN              1.0            NaN
#
#    ResourceW3Schools  ResourceYouTube                        SchoolDegree  \
# 6                NaN              NaN                   bachelor's degree
# 7                NaN              NaN  master's degree (non-professional)
# 8                NaN              NaN                   bachelor's degree
#
#                SchoolMajor  StudentDebtOwe
# 6         Computer Science             NaN
# 7                Education             NaN
# 8  Business Administration             NaN
#
# [3 rows x 113 columns]

# %%
df.columns.values
# Out:
# array(['Age', 'AttendedBootcamp', 'BootcampFinish', 'BootcampFullJobAfter',
#        'BootcampLoanYesNo', 'BootcampMonthsAgo', 'BootcampName',
#        'BootcampPostSalary', 'BootcampRecommend', 'ChildrenNumber',
#        'CityPopulation', 'CodeEventBootcamp', 'CodeEventCoffee',
#        'CodeEventConferences', 'CodeEventDjangoGirls', 'CodeEventGameJam',
#        'CodeEventGirlDev', 'CodeEventHackathons', 'CodeEventMeetup',
#        'CodeEventNodeSchool', 'CodeEventNone', 'CodeEventOther',
#        'CodeEventRailsBridge', 'CodeEventRailsGirls',
#        'CodeEventStartUpWknd', 'CodeEventWomenCode', 'CodeEventWorkshop',
#        'CommuteTime', 'CountryCitizen', 'CountryLive', 'EmploymentField',
#        'EmploymentFieldOther', 'EmploymentStatus', 'EmploymentStatusOther',
#        'ExpectedEarning', 'FinanciallySupporting', 'Gender', 'HasChildren',
#        'HasDebt', 'HasFinancialDependents', 'HasHighSpdInternet',
#        'HasHomeMortgage', 'HasServedInMilitary', 'HasStudentDebt',
#        'HomeMortgageOwe', 'HoursLearning', 'ID.x', 'ID.y', 'Income',
#        'IsEthnicMinority', 'IsReceiveDiabilitiesBenefits', 'IsSoftwareDev',
#        'IsUnderEmployed', 'JobApplyWhen', 'JobPref', 'JobRelocateYesNo',
#        'JobRoleInterest', 'JobRoleInterestOther', 'JobWherePref',
#        'LanguageAtHome', 'MaritalStatus', 'MoneyForLearning',
#        'MonthsProgramming', 'NetworkID', 'Part1EndTime', 'Part1StartTime',
#        'Part2EndTime', 'Part2StartTime', 'PodcastChangeLog',
#        'PodcastCodeNewbie', 'PodcastCodingBlocks', 'PodcastDeveloperTea',
#        'PodcastDotNetRocks', 'PodcastHanselminutes', 'PodcastJSJabber',
#        'PodcastJsAir', 'PodcastNone', 'PodcastOther',
#        'PodcastProgrammingThrowDown', 'PodcastRubyRogues',
#        'PodcastSEDaily', 'PodcastShopTalk', 'PodcastTalkPython',
#        'PodcastWebAhead', 'ResourceBlogs', 'ResourceBooks',
#        'ResourceCodeWars', 'ResourceCodecademy', 'ResourceCoursera',
#        'ResourceDevTips', 'ResourceEdX', 'ResourceEggHead', 'ResourceFCC',
#        'ResourceGoogle', 'ResourceHackerRank', 'ResourceKhanAcademy',
#        'ResourceLynda', 'ResourceMDN', 'ResourceOdinProj', 'ResourceOther',
#        'ResourcePluralSight', 'ResourceReddit', 'ResourceSkillCrush',
#        'ResourceSoloLearn', 'ResourceStackOverflow', 'ResourceTreehouse',
#        'ResourceUdacity', 'ResourceUdemy', 'ResourceW3Schools',
#        'ResourceYouTube', 'SchoolDegree', 'SchoolMajor', 'StudentDebtOwe'], dtype=object)

# %%
df.describe()
# Out:
# /Users/sz2472/.virtualenvs/pandas/lib/python3.5/site-packages/numpy/lib/function_base.py:3823: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#                 Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# count  13613.000000      15380.000000      933.000000            635.000000
# mean      29.175421          0.061964        0.689175              0.584252
# std        9.017716          0.241097        0.463080              0.493239
# min       10.000000          0.000000        0.000000              0.000000
# 25%             NaN               NaN             NaN                   NaN
# 50%             NaN               NaN             NaN                   NaN
# 75%             NaN               NaN             NaN                   NaN
# max       86.000000          1.000000        1.000000              1.000000
#
#        BootcampLoanYesNo  BootcampMonthsAgo  BootcampPostSalary  \
# count         934.000000         631.000000          330.000000
# mean            0.332976           9.055468        63740.506061
# std             0.471531          12.968035        26347.200265
# min             0.000000           0.000000         6000.000000
# 25%                  NaN                NaN                 NaN
# 50%                  NaN                NaN                 NaN
# 75%                  NaN                NaN                 NaN
# max             1.000000         220.000000       200000.000000
#
#        BootcampRecommend  ChildrenNumber  CodeEventBootcamp       ...        \
# count         937.000000     2554.000000               42.0       ...
# mean            0.785486        1.896241                1.0       ...
# std             0.410704        1.115975                0.0       ...
# min             0.000000        0.000000                1.0       ...
# 25%                  NaN             NaN                NaN       ...
# 50%                  NaN             NaN                NaN       ...
# 75%                  NaN             NaN                NaN       ...
# max             1.000000       18.000000                1.0       ...
#
#        ResourceReddit  ResourceSkillCrush  ResourceSoloLearn  \
# count            29.0                36.0               30.0
# mean              1.0                 1.0                1.0
# std               0.0                 0.0                0.0
# min               1.0                 1.0                1.0
# 25%               NaN                 NaN                NaN
# 50%               NaN                 NaN                NaN
# 75%               NaN                 NaN                NaN
# max               1.0                 1.0                1.0
#
#        ResourceStackOverflow  ResourceTreehouse  ResourceUdacity  \
# count                  191.0              422.0           3306.0
# mean                     1.0                1.0              1.0
# std                      0.0                0.0              0.0
# min                      1.0                1.0              1.0
# 25%                      NaN                NaN              NaN
# 50%                      NaN                NaN              NaN
# 75%                      NaN                NaN              NaN
# max                      1.0                1.0              1.0
#
#        ResourceUdemy  ResourceW3Schools  ResourceYouTube  StudentDebtOwe
# count         4130.0              121.0            121.0     3514.000000
# mean             1.0                1.0              1.0    34556.143711
# std              0.0                0.0              0.0    54423.139781
# min              1.0                1.0              1.0        0.000000
# 25%              NaN                NaN              NaN             NaN
# 50%              NaN                NaN              NaN             NaN
# 75%              NaN                NaN              NaN             NaN
# max              1.0                1.0              1.0  1000000.000000
#
# [8 rows x 85 columns]

# %% [markdown]
# ### 1. the youngest programmer vs. the oldest programmer?

# %%
df['Age'].describe()
# Out:
# /Users/sz2472/.virtualenvs/pandas/lib/python3.5/site-packages/numpy/lib/function_base.py:3823: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
# count    13613.000000
# mean        29.175421
# std          9.017716
# min         10.000000
# 25%               NaN
# 50%               NaN
# 75%               NaN
# max         86.000000
# Name: Age, dtype: float64

# %% [markdown]
# ### 2. What are the maximum income for female programmers?

# %%
df.groupby('Gender')['Income'].describe()
# Out:
# /Users/sz2472/.virtualenvs/pandas/lib/python3.5/site-packages/numpy/lib/function_base.py:3823: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
# Gender
# agender      count        14.000000
#              mean      25035.714286
#              std       23329.136854
#              min        6000.000000
#              25%                NaN
#              50%                NaN
#              75%                NaN
#              max      100000.000000
# female       count      1429.000000
#              mean      42982.739678
#              std       29822.084583
#              min        6000.000000
#              25%                NaN
#              50%                NaN
#              75%                NaN
#              max      200000.000000
# genderqueer  count        37.000000
#              mean      36306.270270
#              std       27917.346046
#              min        6000.000000
#              25%                NaN
#              50%                NaN
#              75%                NaN
#              max      150000.000000
# male         count      5815.000000
#              mean      45520.715391
#              std       36918.883898
#              min        6000.000000
#              25%                NaN
#              50%                NaN
#              75%                NaN
#              max      200000.000000
# trans        count        21.000000
#              mean      37714.285714
#              std       25820.811097
#              min        9000.000000
#              25%                NaN
#              50%                NaN
#              75%                NaN
#              max      114000.000000
# Name: Income, dtype: float64

# %% [markdown]
# ### 3. how much does a programmer make on average per year?

# %%
df['Income'].describe()
# Out:
# /Users/sz2472/.virtualenvs/pandas/lib/python3.5/site-packages/numpy/lib/function_base.py:3823: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
# count      7329.000000
# mean      44930.010506
# std       35582.783216
# min        6000.000000
# 25%                NaN
# 50%                NaN
# 75%                NaN
# max      200000.000000
# Name: Income, dtype: float64

# %% [markdown]
# ### 4. what is the most common major programmers studied?

# %%
df['SchoolMajor'].value_counts()
# Out:
# Computer Science                                         1387
# Information Technology                                    408
# Business Administration                                   284
# Economics                                                 252
# Electrical Engineering                                    220
# English                                                   204
# Psychology                                                187
# Electrical and Electronics Engineering                    164
# Software Engineering                                      159
# Liberal Arts                                              157
# Engineering                                               148
# Computer Programming                                      147
# Mechanical Engineering                                    141
# Physics                                                   132
# Political Science                                         131
# Graphic Design                                            129
# Information Systems                                       119
# History                                                   118
# Biology                                                   115
# Finance                                                   114
# Mathematics                                               108
# Communications                                            103
# Computer Software Engineering                             103
# Accounting                                                101
# Math                                                      101
# Philosophy                                                 96
# Business Administration and Management                     83
# Computer and Information Studies                           80
# Linguistics                                                78
# Music                                                      77
#                                                          ...
# Machine Shop Assistant                                      1
# Peace Studies and Conflict Resolution                       1
# Healthcare Administration                                   1
# Sheet Metal Technology                                      1
# Law Studies                                                 1
# International Relations and National Security Studies       1
# Adult Health Nursing                                        1
# Marine Science                                              1
# Building Construction Technology                            1
# Biomedical Sciences and Molecular Medicine                  1
# History Teacher Education                                   1
# Optics                                                      1
# Computer Teacher Education                                  1
# Agricultural and Food Products Processing                   1
# Graphic and Printing Equipment Operation                    1
# Physician Assistant                                         1
# Bilingual  and Multicultural Education                      1
# Public Health Studies                                       1
# Diesel Mechanic                                             1
# School Librarian                                            1
# Police and Criminal Science                                 1
# Animal Grooming                                             1
# South and Southeast Asian Languages and Literatures         1
# Drawing                                                     1
# Optometry                                                   1
# Astronomy                                                   1
# Aerospace Engineering Technician                            1
# Radiation Therapy                                           1
# Selling and Sales                                           1
# Natural Resources Conservation                              1
# Name: SchoolMajor, dtype: int64

# %% [markdown]
# ### 5.what is the highest degree have these programmers completed?

# %%
df['SchoolDegree'].value_counts()
# Out:
# bachelor's degree                           5644
# some college credit, no degree              2268
# master's degree (non-professional)          1445
# high school diploma or equivalent (GED)     1356
# some high school                             764
# professional degree (MBA, MD, JD, etc.)      692
# associate's degree                           649
# trade, technical, or vocational training     443
# no high school (secondary school)            258
# Ph.D.                                        160
# Name: SchoolDegree, dtype: int64

# %% [markdown]
# ### 6. rank programmer with the amount of debt

# %%
df.sort_values(by='StudentDebtOwe', ascending=False).head()
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 5475    NaN               0.0             NaN                   NaN
# 12823  23.0               0.0             NaN                   NaN
# 6570   27.0               0.0             NaN                   NaN
# 14308  26.0               0.0             NaN                   NaN
# 7228   33.0               0.0             NaN                   NaN
#
#        BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 5475                 NaN                NaN          NaN                 NaN
# 12823                NaN                NaN          NaN                 NaN
# 6570                 NaN                NaN          NaN                 NaN
# 14308                NaN                NaN          NaN                 NaN
# 7228                 NaN                NaN          NaN                 NaN
#
#        BootcampRecommend  ChildrenNumber       ...       ResourceSoloLearn  \
# 5475                 NaN             0.0       ...                     NaN
# 12823                NaN             NaN       ...                     NaN
# 6570                 NaN             NaN       ...                     NaN
# 14308                NaN             NaN       ...                     NaN
# 7228                 NaN             NaN       ...                     NaN
#
#        ResourceStackOverflow  ResourceTreehouse  ResourceUdacity  \
# 5475                     NaN                NaN              1.0
# 12823                    NaN                NaN              1.0
# 6570                     NaN                NaN              NaN
# 14308                    NaN                NaN              NaN
# 7228                     NaN                NaN              NaN
#
#        ResourceUdemy  ResourceW3Schools  ResourceYouTube  \
# 5475             1.0                NaN              NaN
# 12823            1.0                NaN              NaN
# 6570             NaN                NaN              NaN
# 14308            NaN                NaN              NaN
# 7228             NaN                NaN              NaN
#
#                                   SchoolDegree             SchoolMajor  \
# 5475                                     Ph.D.                Painting
# 12823  high school diploma or equivalent (GED)                     NaN
# 6570                         bachelor's degree  Film and Video Studies
# 14308           some college credit, no degree                     NaN
# 7228   professional degree (MBA, MD, JD, etc.)                 Physics
#
#        StudentDebtOwe
# 5475        1000000.0
# 12823       1000000.0
# 6570         999999.0
# 14308        999999.0
# 7228         800000.0
#
# [5 rows x 113 columns]

# %% [markdown]
# ### 7. Show programmers are taking loans to attend bootcamp and have full-time job after attending bootcamp?

# %%
df[(df['BootcampFullJobAfter']==1) & (df['BootcampLoanYesNo']==1)].head()
# Out:
#        Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 130   41.0               1.0             1.0                   1.0
# 272   38.0               1.0             1.0                   1.0
# 273   35.0               1.0             1.0                   1.0
# 505   28.0               1.0             1.0                   1.0
# 1442   NaN               1.0             1.0                   1.0
#
#       BootcampLoanYesNo  BootcampMonthsAgo  \
# 130                 1.0               11.0
# 272                 1.0                2.0
# 273                 1.0                8.0
# 505                 1.0                5.0
# 1442                1.0                1.0
#
#                                            BootcampName  BootcampPostSalary  \
# 130                                       Coder Foundry             75000.0
# 272                                         DevMountain             50000.0
# 273                                       The Iron Yard             60000.0
# 505   Free Code Camp is not a bootcamp - please scro...             50000.0
# 1442                                       Hack Reactor             87000.0
#
#       BootcampRecommend  ChildrenNumber       ...       ResourceSoloLearn  \
# 130                 1.0             3.0       ...                     NaN
# 272                 1.0             NaN       ...                     NaN
# 273                 1.0             NaN       ...                     NaN
# 505                 1.0             1.0       ...                     NaN
# 1442                1.0             NaN       ...                     NaN
#
#       ResourceStackOverflow  ResourceTreehouse  ResourceUdacity  \
# 130                     NaN                NaN              NaN
# 272                     NaN                NaN              NaN
# 273                     NaN                NaN              1.0
# 505                     NaN                NaN              NaN
# 1442                    NaN                NaN              NaN
#
#       ResourceUdemy  ResourceW3Schools  ResourceYouTube  \
# 130             1.0                NaN              NaN
# 272             NaN                NaN              NaN
# 273             NaN                NaN              NaN
# 505             1.0                NaN              NaN
# 1442            1.0                NaN              NaN
#
#                         SchoolDegree             SchoolMajor  StudentDebtOwe
# 130   some college credit, no degree                     NaN          8000.0
# 272                bachelor's degree  Structural Engineering             NaN
# 273                bachelor's degree   Public Administration         15000.0
# 505   some college credit, no degree                     NaN         30000.0
# 1442                             NaN                     NaN             NaN
#
# [5 rows x 113 columns]

# %% [markdown]
# ### 8. How many programmers are citizens of United States of America and are ethnic minority?

# %%
df[(df['IsEthnicMinority']==1)& (df['CountryCitizen']=='United States of America')]
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 4      20.0               0.0             NaN                   NaN
# 13      NaN               0.0             NaN                   NaN
# 16     27.0               0.0             NaN                   NaN
# 20     32.0               0.0             NaN                   NaN
# 25     21.0               0.0             NaN                   NaN
# 28     25.0               0.0             NaN                   NaN
# 30     24.0               0.0             NaN                   NaN
# 34     33.0               0.0             NaN                   NaN
# 49     20.0               0.0             NaN                   NaN
# 66     25.0               0.0             NaN                   NaN
# 67     27.0               0.0             NaN                   NaN
# 71     37.0               0.0             NaN                   NaN
# 77     36.0               0.0             NaN                   NaN
# 82     32.0               0.0             NaN                   NaN
# 93     32.0               1.0             1.0                   0.0
# 96     23.0               0.0             NaN                   NaN
# 99     25.0               0.0             NaN                   NaN
# 101    31.0               0.0             NaN                   NaN
# 103    19.0               0.0             NaN                   NaN
# 110    26.0               0.0             NaN                   NaN
# 129    24.0               0.0             NaN                   NaN
# 133    22.0               0.0             NaN                   NaN
# 138    22.0               0.0             NaN                   NaN
# 147    34.0               0.0             NaN                   NaN
# 152    29.0               0.0             NaN                   NaN
# 170    29.0               0.0             NaN                   NaN
# 176    26.0               0.0             NaN                   NaN
# 177    19.0               0.0             NaN                   NaN
# 181    27.0               0.0             NaN                   NaN
# 199    22.0               0.0             NaN                   NaN
# ...     ...               ...             ...                   ...
# 15160  22.0               0.0             NaN                   NaN
# 15177  36.0               0.0             NaN                   NaN
# 15179  28.0               0.0             NaN                   NaN
# 15180  18.0               0.0             NaN                   NaN
# 15186  21.0               0.0             NaN                   NaN
# 15189  22.0               0.0             NaN                   NaN
# 15193  20.0               0.0             NaN                   NaN
# 15195  19.0               0.0             NaN                   NaN
# 15221  25.0               0.0             NaN                   NaN
# 15241  23.0               0.0             NaN                   NaN
# 15261  23.0               0.0             NaN                   NaN
# 15279  19.0               0.0             NaN                   NaN
# 15291  18.0               0.0             NaN                   NaN
# 15305  25.0               0.0             NaN                   NaN
# 15307  21.0               0.0             NaN                   NaN
# 15324  21.0               0.0             NaN                   NaN
# 15356  30.0               0.0             NaN                   NaN
# 15362  25.0               0.0             NaN                   NaN
# 15368  19.0               0.0             NaN                   NaN
# 15370  25.0               0.0             NaN                   NaN
# 15503  40.0               0.0             NaN                   NaN
# 15505  26.0               0.0             NaN                   NaN
# 15513  19.0               0.0             NaN                   NaN
# 15514  23.0               0.0             NaN                   NaN
# 15515  22.0               0.0             NaN                   NaN
# 15563  38.0               0.0             NaN                   NaN
# 15569  35.0               0.0             NaN                   NaN
# 15572  48.0               0.0             NaN                   NaN
# 15601  25.0               0.0             NaN                   NaN
# 15614  47.0               0.0             NaN                   NaN
#
#        BootcampLoanYesNo  BootcampMonthsAgo    BootcampName  \
# 4                    NaN                NaN             NaN
# 13                   NaN                NaN             NaN
# 16                   NaN                NaN             NaN
# 20                   NaN                NaN             NaN
# 25                   NaN                NaN             NaN
# 28                   NaN                NaN             NaN
# 30                   NaN                NaN             NaN
# 34                   NaN                NaN             NaN
# 49                   NaN                NaN             NaN
# 66                   NaN                NaN             NaN
# 67                   NaN                NaN             NaN
# 71                   NaN                NaN             NaN
# 77                   NaN                NaN             NaN
# 82                   NaN                NaN             NaN
# 93                   0.0                8.0  Codify Academy
# 96                   NaN                NaN             NaN
# 99                   NaN                NaN             NaN
# 101                  NaN                NaN             NaN
# 103                  NaN                NaN             NaN
# 110                  NaN                NaN             NaN
# 129                  NaN                NaN             NaN
# 133                  NaN                NaN             NaN
# 138                  NaN                NaN             NaN
# 147                  NaN                NaN             NaN
# 152                  NaN                NaN             NaN
# 170                  NaN                NaN             NaN
# 176                  NaN                NaN             NaN
# 177                  NaN                NaN             NaN
# 181                  NaN                NaN             NaN
# 199                  NaN                NaN             NaN
# ...                  ...                ...             ...
# 15160                NaN                NaN             NaN
# 15177                NaN                NaN             NaN
# 15179                NaN                NaN             NaN
# 15180                NaN                NaN             NaN
# 15186                NaN                NaN             NaN
# 15189                NaN                NaN             NaN
# 15193                NaN                NaN             NaN
# 15195                NaN                NaN             NaN
# 15221                NaN                NaN             NaN
# 15241                NaN                NaN             NaN
# 15261                NaN                NaN             NaN
# 15279                NaN                NaN             NaN
# 15291                NaN                NaN             NaN
# 15305                NaN                NaN             NaN
# 15307                NaN                NaN             NaN
# 15324                NaN                NaN             NaN
# 15356                NaN                NaN             NaN
# 15362                NaN                NaN             NaN
# 15368                NaN                NaN             NaN
# 15370                NaN                NaN             NaN
# 15503                NaN                NaN             NaN
# 15505                NaN                NaN             NaN
# 15513                NaN                NaN             NaN
# 15514                NaN                NaN             NaN
# 15515                NaN                NaN             NaN
# 15563                NaN                NaN             NaN
# 15569                NaN                NaN             NaN
# 15572                NaN                NaN             NaN
# 15601                NaN                NaN             NaN
# 15614                NaN                NaN             NaN
#
#        BootcampPostSalary  BootcampRecommend  ChildrenNumber       ...        \
# 4                     NaN                NaN             NaN       ...
# 13                    NaN                NaN             NaN       ...
# 16                    NaN                NaN             NaN       ...
# 20                    NaN                NaN             1.0       ...
# 25                    NaN                NaN             NaN       ...
# 28                    NaN                NaN             NaN       ...
# 30                    NaN                NaN             NaN       ...
# 34                    NaN                NaN             NaN       ...
# 49                    NaN                NaN             NaN       ...
# 66                    NaN                NaN             NaN       ...
# 67                    NaN                NaN             NaN       ...
# 71                    NaN                NaN             1.0       ...
# 77                    NaN                NaN             1.0       ...
# 82                    NaN                NaN             NaN       ...
# 93                    NaN                0.0             NaN       ...
# 96                    NaN                NaN             NaN       ...
# 99                    NaN                NaN             NaN       ...
# 101                   NaN                NaN             NaN       ...
# 103                   NaN                NaN             NaN       ...
# 110                   NaN                NaN             NaN       ...
# 129                   NaN                NaN             NaN       ...
# 133                   NaN                NaN             NaN       ...
# 138                   NaN                NaN             NaN       ...
# 147                   NaN                NaN             1.0       ...
# 152                   NaN                NaN             NaN       ...
# 170                   NaN                NaN             NaN       ...
# 176                   NaN                NaN             NaN       ...
# 177                   NaN                NaN             NaN       ...
# 181                   NaN                NaN             NaN       ...
# 199                   NaN                NaN             NaN       ...
# ...                   ...                ...             ...       ...
# 15160                 NaN                NaN             NaN       ...
# 15177                 NaN                NaN             NaN       ...
# 15179                 NaN                NaN             NaN       ...
# 15180                 NaN                NaN             NaN       ...
# 15186                 NaN                NaN             NaN       ...
# 15189                 NaN                NaN             NaN       ...
# 15193                 NaN                NaN             NaN       ...
# 15195                 NaN                NaN             NaN       ...
# 15221                 NaN                NaN             NaN       ...
# 15241                 NaN                NaN             NaN       ...
# 15261                 NaN                NaN             NaN       ...
# 15279                 NaN                NaN             NaN       ...
# 15291                 NaN                NaN             NaN       ...
# 15305                 NaN                NaN             NaN       ...
# 15307                 NaN                NaN             NaN       ...
# 15324                 NaN                NaN             NaN       ...
# 15356                 NaN                NaN             NaN       ...
# 15362                 NaN                NaN             NaN       ...
# 15368                 NaN                NaN             NaN       ...
# 15370                 NaN                NaN             NaN       ...
# 15503                 NaN                NaN             NaN       ...
# 15505                 NaN                NaN             NaN       ...
# 15513                 NaN                NaN             NaN       ...
# 15514                 NaN                NaN             NaN       ...
# 15515                 NaN                NaN             NaN       ...
# 15563                 NaN                NaN             NaN       ...
# 15569                 NaN                NaN             2.0       ...
# 15572                 NaN                NaN             2.0       ...
# 15601                 NaN                NaN             NaN       ...
# 15614                 NaN                NaN             NaN       ...
#
#       ResourceSoloLearn  ResourceStackOverflow  ResourceTreehouse  \
# 4                   NaN                    NaN                NaN
# 13                  NaN                    NaN                NaN
# 16                  NaN                    NaN                NaN
# 20                  NaN                    NaN                NaN
# 25                  NaN                    NaN                NaN
# 28                  NaN                    NaN                NaN
# 30                  NaN                    NaN                NaN
# 34                  NaN                    NaN                NaN
# 49                  NaN                    NaN                NaN
# 66                  NaN                    NaN                NaN
# 67                  NaN                    NaN                NaN
# 71                  NaN                    NaN                NaN
# 77                  NaN                    NaN                NaN
# 82                  NaN                    NaN                NaN
# 93                  NaN                    NaN                NaN
# 96                  NaN                    NaN                NaN
# 99                  NaN                    NaN                NaN
# 101                 NaN                    NaN                NaN
# 103                 NaN                    NaN                NaN
# 110                 NaN                    NaN                NaN
# 129                 NaN                    NaN                NaN
# 133                 NaN                    NaN                NaN
# 138                 NaN                    NaN                NaN
# 147                 NaN                    NaN                NaN
# 152                 NaN                    NaN                NaN
# 170                 NaN                    NaN                1.0
# 176                 NaN                    NaN                NaN
# 177                 NaN                    NaN                NaN
# 181                 NaN                    NaN                NaN
# 199                 NaN                    NaN                NaN
# ...                 ...                    ...                ...
# 15160               NaN                    NaN                NaN
# 15177               NaN                    NaN                NaN
# 15179               NaN                    NaN                NaN
# 15180               NaN                    NaN                NaN
# 15186               NaN                    NaN                NaN
# 15189               NaN                    NaN                NaN
# 15193               NaN                    NaN                NaN
# 15195               NaN                    NaN                NaN
# 15221               NaN                    NaN                NaN
# 15241               NaN                    NaN                NaN
# 15261               NaN                    NaN                NaN
# 15279               NaN                    NaN                NaN
# 15291               NaN                    NaN                NaN
# 15305               NaN                    NaN                NaN
# 15307               NaN                    NaN                NaN
# 15324               NaN                    NaN                NaN
# 15356               NaN                    NaN                NaN
# 15362               NaN                    NaN                NaN
# 15368               NaN                    NaN                NaN
# 15370               NaN                    NaN                NaN
# 15503               NaN                    NaN                NaN
# 15505               NaN                    NaN                NaN
# 15513               NaN                    NaN                NaN
# 15514               NaN                    NaN                1.0
# 15515               NaN                    NaN                NaN
# 15563               NaN                    NaN                NaN
# 15569               NaN                    1.0                NaN
# 15572               NaN                    NaN                NaN
# 15601               NaN                    NaN                NaN
# 15614               NaN                    NaN                NaN
#
#        ResourceUdacity  ResourceUdemy  ResourceW3Schools  ResourceYouTube  \
# 4                  NaN            NaN                NaN              NaN
# 13                 NaN            NaN                NaN              NaN
# 16                 1.0            NaN                NaN              NaN
# 20                 1.0            1.0                NaN              NaN
# 25                 NaN            NaN                NaN              NaN
# 28                 NaN            NaN                NaN              NaN
# 30                 NaN            1.0                NaN              NaN
# 34                 1.0            NaN                NaN              NaN
# 49                 1.0            1.0                NaN              NaN
# 66                 NaN            NaN                NaN              NaN
# 67                 1.0            1.0                NaN              NaN
# 71                 NaN            NaN                NaN              NaN
# 77                 1.0            NaN                NaN              NaN
# 82                 NaN            NaN                NaN              NaN
# 93                 1.0            NaN                NaN              NaN
# 96                 NaN            NaN                NaN              NaN
# 99                 1.0            NaN                NaN              NaN
# 101                NaN            NaN                NaN              NaN
# 103                1.0            1.0                NaN              NaN
# 110                NaN            NaN                NaN              NaN
# 129                1.0            NaN                NaN              NaN
# 133                NaN            NaN                NaN              NaN
# 138                NaN            1.0                NaN              NaN
# 147                NaN            NaN                NaN              NaN
# 152                NaN            NaN                NaN              NaN
# 170                NaN            NaN                NaN              NaN
# 176                NaN            NaN                NaN              NaN
# 177                NaN            NaN                NaN              NaN
# 181                NaN            NaN                NaN              NaN
# 199                1.0            NaN                NaN              NaN
# ...                ...            ...                ...              ...
# 15160              NaN            NaN                NaN              NaN
# 15177              NaN            NaN                NaN              NaN
# 15179              NaN            NaN                NaN              NaN
# 15180              NaN            NaN                NaN              NaN
# 15186              NaN            NaN                NaN              NaN
# 15189              NaN            NaN                NaN              NaN
# 15193              NaN            NaN                NaN              NaN
# 15195              NaN            NaN                NaN              NaN
# 15221              NaN            NaN                NaN              NaN
# 15241              1.0            NaN                NaN              NaN
# 15261              NaN            NaN                NaN              NaN
# 15279              1.0            1.0                NaN              NaN
# 15291              NaN            NaN                NaN              NaN
# 15305              NaN            1.0                NaN              NaN
# 15307              NaN            NaN                NaN              NaN
# 15324              NaN            NaN                NaN              NaN
# 15356              1.0            NaN                NaN              NaN
# 15362              1.0            NaN                NaN              NaN
# 15368              NaN            NaN                NaN              NaN
# 15370              NaN            NaN                NaN              NaN
# 15503              1.0            NaN                NaN              NaN
# 15505              NaN            NaN                NaN              NaN
# 15513              NaN            NaN                NaN              NaN
# 15514              1.0            NaN                NaN              NaN
# 15515              NaN            NaN                NaN              NaN
# 15563              NaN            1.0                NaN              NaN
# 15569              NaN            NaN                NaN              NaN
# 15572              NaN            NaN                NaN              NaN
# 15601              1.0            1.0                NaN              NaN
# 15614              NaN            NaN                NaN              NaN
#
#                                    SchoolDegree  \
# 4                some college credit, no degree
# 13                            bachelor's degree
# 16                            bachelor's degree
# 20           master's degree (non-professional)
# 25               some college credit, no degree
# 28                            bachelor's degree
# 30               some college credit, no degree
# 34                            bachelor's degree
# 49      high school diploma or equivalent (GED)
# 66                            bachelor's degree
# 67                           associate's degree
# 71               some college credit, no degree
# 77           master's degree (non-professional)
# 82                            bachelor's degree
# 93                            bachelor's degree
# 96               some college credit, no degree
# 99                            bachelor's degree
# 101                           bachelor's degree
# 103              some college credit, no degree
# 110                           bachelor's degree
# 129                           bachelor's degree
# 133                           bachelor's degree
# 138                          associate's degree
# 147              some college credit, no degree
# 152     high school diploma or equivalent (GED)
# 170     professional degree (MBA, MD, JD, etc.)
# 176                           bachelor's degree
# 177              some college credit, no degree
# 181          master's degree (non-professional)
# 199              some college credit, no degree
# ...                                         ...
# 15160   high school diploma or equivalent (GED)
# 15177                         bachelor's degree
# 15179                         bachelor's degree
# 15180            some college credit, no degree
# 15186            some college credit, no degree
# 15189   high school diploma or equivalent (GED)
# 15193   high school diploma or equivalent (GED)
# 15195   high school diploma or equivalent (GED)
# 15221            some college credit, no degree
# 15241                         bachelor's degree
# 15261            some college credit, no degree
# 15279                         bachelor's degree
# 15291   high school diploma or equivalent (GED)
# 15305            some college credit, no degree
# 15307                          some high school
# 15324            some college credit, no degree
# 15356            some college credit, no degree
# 15362                        associate's degree
# 15368   high school diploma or equivalent (GED)
# 15370            some college credit, no degree
# 15503                         bachelor's degree
# 15505            some college credit, no degree
# 15513            some college credit, no degree
# 15514                         bachelor's degree
# 15515                         bachelor's degree
# 15563                         bachelor's degree
# 15569                         bachelor's degree
# 15572                         bachelor's degree
# 15601                         bachelor's degree
# 15614  trade, technical, or vocational training
#
#                                SchoolMajor  StudentDebtOwe
# 4                                      NaN             NaN
# 13                 Business Administration         12000.0
# 16                               Economics             NaN
# 20                                 Geology             NaN
# 25                                     NaN         40000.0
# 28                       Political Science             NaN
# 30                                     NaN             NaN
# 34                                 English         44000.0
# 49                                     NaN             NaN
# 66                               Economics             NaN
# 67                 Business Administration             NaN
# 71                                     NaN         50000.0
# 77                        Computer Science             NaN
# 82                  Electrical Engineering             NaN
# 93                                 Biology             NaN
# 96                                     NaN          7000.0
# 99                            Anthropology         20000.0
# 101                           Liberal Arts             NaN
# 103                                    NaN             NaN
# 110                                Biology         11400.0
# 129                         Communications             NaN
# 133                 Information Technology             NaN
# 138                 Electrical Engineering             NaN
# 147                                    NaN         18000.0
# 152                                    NaN             NaN
# 170                              Economics        115000.0
# 176                      Industrial Design         30000.0
# 177                                    NaN             NaN
# 181                                Finance             NaN
# 199                                    NaN          2000.0
# ...                                    ...             ...
# 15160                                  NaN             NaN
# 15177                         Anthropology         40000.0
# 15179                    Computer Graphics         60000.0
# 15180                                  NaN         15000.0
# 15186                                  NaN             NaN
# 15189                                  NaN             NaN
# 15193                                  NaN             NaN
# 15195                                  NaN             NaN
# 15221                                  NaN         60000.0
# 15241               Biomedical Engineering         50000.0
# 15261                                  NaN         15000.0
# 15279                     Computer Science         69000.0
# 15291                                  NaN             NaN
# 15305                                  NaN         30000.0
# 15307                                  NaN             NaN
# 15324                                  NaN             NaN
# 15356                                  NaN         26000.0
# 15362                      General Studies             NaN
# 15368                                  NaN             NaN
# 15370                                  NaN         25000.0
# 15503                  Information Systems         50000.0
# 15505                                  NaN             NaN
# 15513                                  NaN         20000.0
# 15514                                 Math         35000.0
# 15515                           Psychology         55000.0
# 15563                              Physics             NaN
# 15569                     Computer Science          3000.0
# 15572                          Art History         12000.0
# 15601  Criminal Justice and Safety Studies             NaN
# 15614                                  NaN             NaN
#
# [1815 rows x 113 columns]

# %% [markdown]
# ### 9.programmers from which country earn the most?

# %%
df.groupby('CountryCitizen')['Income'].sum().sort_values(ascending=False)
# Out:
# CountryCitizen
# United States of America         194609044.0
# India                             18026086.0
# United Kingdom                    13838710.0
# Canada                            13017128.0
# Australia                          6241505.0
# Brazil                             5003055.0
# Russia                             3884165.0
# Germany                            3622212.0
# Ukraine                            3286720.0
# Netherlands (Holland, Europe)      2582216.0
# France                             2444481.0
# Romania                            2411659.0
# Poland                             2316574.0
# Mexico                             2314810.0
# Spain                              2291985.0
# Philippines                        2214142.0
# Venezuela                          2105128.0
# South Africa                       2092398.0
# Nigeria                            1929112.0
# Italy                              1916690.0
# Portugal                           1668800.0
# Ireland                            1531500.0
# Sweden                             1343583.0
# New Zealand                        1147653.0
# Colombia                           1123315.0
# Indonesia                          1076398.0
# Serbia                             1076200.0
# Norway                             1070550.0
# China                              1055800.0
# Turkey                             1018000.0
#                                     ...
# Togo                                 14400.0
# Cape Verde                           14000.0
# Martinique                           14000.0
# Dominica                              9600.0
# Angola                                   NaN
# Antigua & Barbuda                        NaN
# Armenia                                  NaN
# Bermuda                                  NaN
# Congo                                    NaN
# Eritrea                                  NaN
# Grenada                                  NaN
# Guam                                     NaN
# Hawaii                                   NaN
# Korea North                              NaN
# Kuwait                                   NaN
# Lesotho                                  NaN
# Libya                                    NaN
# Madagascar                               NaN
# Mauritius                                NaN
# Myanmar                                  NaN
# Nambia                                   NaN
# Netherland Antilles                      NaN
# Nicaragua                                NaN
# Palestine                                NaN
# Republic of Montenegro                   NaN
# Rwanda                                   NaN
# Somalia                                  NaN
# Tanzania                                 NaN
# United Arab Emirates                     NaN
# Zambia                                   NaN
# Name: Income, dtype: float64

# %% [markdown]
# ### 10. How many programmers found jobs after graduating from bootcamp less and equal than 4 months?

# %%
df['BootcampMonthsAgo'].value_counts()
# Out:
# 1.0      77
# 3.0      64
# 12.0     48
# 2.0      43
# 4.0      42
# 6.0      42
# 5.0      36
# 0.0      29
# 24.0     27
# 8.0      27
# 7.0      26
# 9.0      23
# 18.0     21
# 15.0     18
# 14.0     15
# 10.0     15
# 11.0     14
# 20.0     12
# 16.0      8
# 21.0      6
# 13.0      6
# 22.0      4
# 19.0      4
# 27.0      4
# 17.0      4
# 23.0      3
# 28.0      2
# 30.0      2
# 26.0      1
# 156.0     1
# 32.0      1
# 36.0      1
# 37.0      1
# 42.0      1
# 50.0      1
# 72.0      1
# 220.0     1
# Name: BootcampMonthsAgo, dtype: int64

# %%
df[(df['EmploymentStatus']== 'Employed for wages')& (df['BootcampMonthsAgo'] <=4)].head()
# Out:
#        Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 97    26.0               1.0             1.0                   1.0
# 272   38.0               1.0             1.0                   1.0
# 1803  35.0               1.0             1.0                   1.0
# 1866  44.0               1.0             1.0                   0.0
# 1913  28.0               1.0             1.0                   0.0
#
#       BootcampLoanYesNo  BootcampMonthsAgo          BootcampName  \
# 97                  0.0                3.0        DaVinci Coders
# 272                 1.0                2.0           DevMountain
# 1803                0.0                3.0      General Assembly
# 1866                0.0                3.0          Code Fellows
# 1913                0.0                1.0  The Firehose Project
#
#       BootcampPostSalary  BootcampRecommend  ChildrenNumber       ...        \
# 97               45000.0                0.0             NaN       ...
# 272              50000.0                1.0             NaN       ...
# 1803             41600.0                1.0             1.0       ...
# 1866                 NaN                1.0             NaN       ...
# 1913                 NaN                0.0             NaN       ...
#
#      ResourceSoloLearn  ResourceStackOverflow  ResourceTreehouse  \
# 97                 NaN                    NaN                NaN
# 272                NaN                    NaN                NaN
# 1803               NaN                    NaN                NaN
# 1866               NaN                    NaN                NaN
# 1913               NaN                    NaN                NaN
#
#       ResourceUdacity  ResourceUdemy  ResourceW3Schools  ResourceYouTube  \
# 97                NaN            1.0                NaN              NaN
# 272               NaN            NaN                NaN              NaN
# 1803              NaN            NaN                NaN              NaN
# 1866              NaN            NaN                NaN              NaN
# 1913              NaN            NaN                NaN              NaN
#
#                                   SchoolDegree             SchoolMajor  \
# 97          master's degree (non-professional)                   Music
# 272                          bachelor's degree  Structural Engineering
# 1803                         bachelor's degree            Liberal Arts
# 1866  trade, technical, or vocational training                     NaN
# 1913                         bachelor's degree  Information Technology
#
#       StudentDebtOwe
# 97           80000.0
# 272              NaN
# 1803             NaN
# 1866             NaN
# 1913             NaN
#
# [5 rows x 113 columns]

# %% [markdown]
# ### this is a bar chart of programmers' age

# %%
df['Age'].hist()

# %%
plt.style.available
# Out:
# ['classic',
#  'seaborn-deep',
#  'seaborn-pastel',
#  'seaborn-ticks',
#  'seaborn-notebook',
#  'dark_background',
#  'seaborn-paper',
#  'bmh',
#  'fivethirtyeight',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'ggplot',
#  'seaborn-muted',
#  'grayscale',
#  'seaborn-poster',
#  'seaborn-colorblind',
#  'seaborn-talk',
#  'seaborn-darkgrid',
#  'seaborn-bright']

# %% [markdown]
# ### change the style of the previous plot into fivethirtyeight

# %%
plt.style.use('fivethirtyeight')

# %%
df['Age'].hist()

# %% [markdown]
# ### customize the chart by changing bin size, xlabelsize, ylabelsize and range

# %%
df['Age'].hist(bins=50, xlabelsize=10, ylabelsize=10, range=(0,50))# number of bins tells different stories

# %% [markdown]
# ### Make a graph that shows the amount of student debt the first 10 programmes from the dataframe own?

# %%
plt.style.use('fivethirtyeight')
df['StudentDebtOwe'].head(10).plot(kind='bar')
